# %% [markdown]
# ![Screenshot 2026-03-01 005605.png](attachment:bca19fc5-724a-46ac-962f-064d445d884f.png)

# %% [markdown]
# ![Screenshot 2026-03-01 005616.png](attachment:bd071c22-1684-45f2-9d87-5ed4cb7d4a45.png)

# %% [markdown]
# ![Screenshot 2026-03-01 005622.png](attachment:7368d2c8-ca74-43db-977d-9311fe40d8f4.png)
